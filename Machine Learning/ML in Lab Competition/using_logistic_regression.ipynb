# %%
#imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.linear_model import LogisticRegression
from tensorflow import keras
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
df_train.head()
# Out:
#      ID         A         B         C         D         E         F         G  \
# 0  1000  0.571201  1.063409 -0.303041  1.602098 -0.122985  1.120129  2.296855
# 1  1001 -0.143132  1.246863 -0.121985  0.879625  0.265433 -0.110920  0.019004
# 2  1002  1.285398 -0.128818  0.526318 -0.953757  0.193953 -0.132575 -0.372182
# 3  1003  0.032639 -0.286153  0.922083 -0.928660  0.835517  0.320709  0.293862
# 4  1004  2.267892  1.364222  0.277339  0.652962 -0.364164  1.249994 -0.363552
#
#           H         I         J    Y
# 0  1.922802  2.744089 -0.281714  0.0
# 1 -0.014329 -0.733068 -0.761596  1.0
# 2  0.222577 -0.055932 -0.414822  1.0
# 3 -0.163273  1.176671  0.322280  1.0
# 4  0.593542  0.277651  0.589408  0.0

# %%
# Checking Null values
df_train.isnull().sum()
# Out:
# ID    0
# A     0
# B     0
# C     0
# D     0
# E     0
# F     0
# G     0
# H     0
# I     0
# J     0
# Y     0
# dtype: int64

# %%
# NO Null Values

# %% [markdown]
# ### Preprocessing the data

# %%
# Dropping column "ID" and Column "Y" as id just gives number and Y is the actual output
# I am also dropping from training Set
X_train = df_train.drop(columns=["ID", "Y"])  
# Labels
y_train = df_train["Y"]

# %%
# Features (test set)
X_test = df_test.drop(columns=["ID"])  
# Save IDs for submission
test_ids = df_test["ID"]

# %%
# Normalize the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### Logistic Regression to be in the leaderboard

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ## Checking The Accuracy

# %%
# Making predictions on training data just for checking
y_train_pred = model.predict(X_train)


accuracy = accuracy_score(y_train, y_train_pred) 
f1 = f1_score(y_train, y_train_pred)

print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Accuracy: 0.8805
# F1 Score: 0.6887

# %%
# Predicting 0-1 Output 
y_pred = model.predict(X_test)

# %% [markdown]
# ### Submission File

# %%
submission = pd.DataFrame({"ID": test_ids, "Y": y_pred})
submission.to_csv("submission.csv", index=False)

print("File saved as submission.csv")
# Out:
# File saved as submission.csv
